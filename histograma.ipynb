# %% [markdown]
# # histograma

# %%
import random
a = 5
b = 3 
c = 16 #modulo
Xo = 7

#Xn = (((a*Xo) + 3 ) % c )
#Xo = Xn
for i in range (0, 1000) :
    Xn = (((a*Xo) + 3 ) % c )
    Xo = Xn 
 
    print "ope.compl", Xn 

    

from matplotlib.pylab import hist, show
f=range(0,1000)
data=[]
for i in range(1000):
    data.append(random.choice(f))

hist(data,200, (0,1000))
show()
# Out:
# ope.compl 6
# ope.compl 1
# ope.compl 8
# ope.compl 11
# ope.compl 10
# ope.compl 5
# ope.compl 12
# ope.compl 15
# ope.compl 14
# ope.compl 9
# ope.compl 0
# ope.compl 3
# ope.compl 2
# ope.compl 13
# ope.compl 4
# ope.compl 7
# ope.compl 6
# ope.compl 1
# ope.compl 8
# ope.compl 11
# ope.compl 10
# ope.compl 5
# ope.compl 12
# ope.compl 15
# ope.compl 14
# ope.compl 9
# ope.compl 0
# ope.compl 3
# ope.compl 2
# ope.compl 13
# ope.compl 4
# ope.compl 7
# ope.compl 6
# ope.compl 1
# ope.compl 8
# ope.compl 11
# ope.compl 10
# ope.compl 5
# ope.compl 12
# ope.compl 15
# ope.compl 14
# ope.compl 9
# ope.compl 0
# ope.compl 3
# ope.compl 2
# ope.compl 13
# ope.compl 4
# ope.compl 7
# ope.compl 6
# ope.compl 1
# ope.compl 8
# ope.compl 11
# ope.compl 10
# ope.compl 5
# ope.compl 12
# ope.compl 15
# ope.compl 14
# ope.compl 9
# ope.compl 0
# ope.compl 3
# ope.compl 2
# ope.compl 13
# ope.compl 4
# ope.compl 7
# ope.compl 6
# ope.compl 1
# ope.compl 8
# ope.compl 11
# ope.compl 10
# ...
